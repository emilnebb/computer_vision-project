# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
dataset_stats = []
with open('dataset_stats.json') as f:
    dataset_stats = json.load(f)

# %%
print(dataset_stats[0])

for stats in dataset_stats[:10]:

    plt.bar(*zip(*stats.items()))
    plt.show()
# Out:
# {'background': 0, 'car': 0.15141031210960318, 'truck': 0.0016645930035039669, 'bus': 0, 'motorcycle': 0, 'bicycle': 0, 'scooter': 0, 'person': 0.01253916628931151, 'rider': 0.006739904040376832}
